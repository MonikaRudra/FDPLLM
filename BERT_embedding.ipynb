# %% [markdown]
# <a href="https://colab.research.google.com/github/MonikaRudra/FDPLLM/blob/main/BERT_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import BertModel,BertTokenizer

# %%
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
sample_text = "quick brown fox jumped over lazy dog"

# %% [markdown]
# Encode the input text

# %%
input_id=tokenizer.encode(sample_text, return_tensors ='pt')

# %%
import torch
with torch.no_grad():
  embedding=model(input_id)[0]

# %%
embedding
# Out:
# tensor([[[-0.4304, -0.1367, -0.1344,  ..., -0.3486,  0.4083,  0.4738],
#          [-0.2634, -0.5571,  0.2601,  ..., -0.3385,  0.6249, -0.2374],
#          [ 0.2763, -0.1947,  0.3890,  ..., -0.7960,  0.0098, -0.2442],
#          ...,
#          [-0.0742, -0.4365,  0.2878,  ..., -0.2909,  0.0695, -0.4611],
#          [-0.0764, -0.4931, -0.3786,  ..., -0.1166,  0.2202,  0.1860],
#          [ 0.7450, -0.0026, -0.3293,  ...,  0.2632, -0.3474, -0.1385]]])

# %%
embedding.shape
# Out:
# torch.Size([1, 9, 768])
